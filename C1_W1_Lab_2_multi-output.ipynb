# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)
# Out:
#                X1          X2          X3          X4          X5          X6  \
# count  614.000000  614.000000  614.000000  614.000000  614.000000  614.000000
# mean     0.764691  671.236156  319.537459  175.849349    5.278502    3.550489
# std      0.106008   88.302944   44.108648   45.223968    1.751195    1.125077
# min      0.620000  514.500000  245.000000  110.250000    3.500000    2.000000
# 25%      0.660000  612.500000  294.000000  122.500000    3.500000    3.000000
# 50%      0.760000  661.500000  318.500000  147.000000    7.000000    4.000000
# 75%      0.820000  759.500000  343.000000  220.500000    7.000000    5.000000
# max      0.980000  808.500000  416.500000  220.500000    7.000000    5.000000
#
#                X7          X8
# count  614.000000  614.000000
# mean     0.235668    2.848534
# std      0.133034    1.552199
# min      0.000000    0.000000
# 25%      0.100000    2.000000
# 50%      0.250000    3.000000
# 75%      0.400000    4.000000
# max      0.400000    5.000000

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 250.5133 - y1_output_loss: 122.8347 - y2_output_loss: 125.7862 - y1_output_root_mean_squared_error: 11.1325 - y2_output_root_mean_squared_error: 11.2508 - val_loss: 92.9955 - val_y1_output_loss: 26.8517 - val_y2_output_loss: 70.9931 - val_y1_output_root_mean_squared_error: 5.0864 - val_y2_output_root_mean_squared_error: 8.1929
# Epoch 2/500
# 614/614 [==============================] - 0s 169us/sample - loss: 32.1170 - y1_output_loss: 12.4348 - y2_output_loss: 19.4174 - y1_output_root_mean_squared_error: 3.5385 - y2_output_root_mean_squared_error: 4.4267 - val_loss: 24.4505 - val_y1_output_loss: 10.6510 - val_y2_output_loss: 15.1566 - val_y1_output_root_mean_squared_error: 3.2361 - val_y2_output_root_mean_squared_error: 3.7387
# Epoch 3/500
# 614/614 [==============================] - 0s 167us/sample - loss: 26.7382 - y1_output_loss: 10.3230 - y2_output_loss: 16.2797 - y1_output_root_mean_squared_error: 3.2179 - y2_output_root_mean_squared_error: 4.0477 - val_loss: 27.8597 - val_y1_output_loss: 12.0362 - val_y2_output_loss: 18.2468 - val_y1_output_root_mean_squared_error: 3.3845 - val_y2_output_root_mean_squared_error: 4.0503
# Epoch 4/500
# 614/614 [==============================] - 0s 145us/sample - loss: 24.6067 - y1_output_loss: 9.3279 - y2_output_loss: 15.2024 - y1_output_root_mean_squared_error: 3.0501 - y2_output_root_mean_squared_error: 3.9120 - val_loss: 21.8560 - val_y1_output_loss: 9.1505 - val_y2_output_loss: 13.3043 - val_y1_output_root_mean_squared_error: 3.0238 - val_y2_output_root_mean_squared_error: 3.5655
# Epoch 5/500
# 614/614 [==============================] - 0s 146us/sample - loss: 23.1981 - y1_output_loss: 8.8013 - y2_output_loss: 14.3299 - y1_output_root_mean_squared_error: 2.9567 - y2_output_root_mean_squared_error: 3.8021 - val_loss: 31.4011 - val_y1_output_loss: 12.7396 - val_y2_output_loss: 18.1949 - val_y1_output_root_mean_squared_error: 3.6158 - val_y2_output_root_mean_squared_error: 4.2810
# Epoch 6/500
# 614/614 [==============================] - 0s 157us/sample - loss: 20.7002 - y1_output_loss: 8.6738 - y2_output_loss: 11.9089 - y1_output_root_mean_squared_error: 2.9523 - y2_output_root_mean_squared_error: 3.4618 - val_loss: 19.7387 - val_y1_output_loss: 8.5786 - val_y2_output_loss: 12.1388 - val_y1_output_root_mean_squared_error: 2.9010 - val_y2_output_root_mean_squared_error: 3.3650
# Epoch 7/500
# 614/614 [==============================] - 0s 150us/sample - loss: 22.4491 - y1_output_loss: 8.3675 - y2_output_loss: 13.8811 - y1_output_root_mean_squared_error: 2.9057 - y2_output_root_mean_squared_error: 3.7425 - val_loss: 25.6678 - val_y1_output_loss: 10.6015 - val_y2_output_loss: 16.8847 - val_y1_output_root_mean_squared_error: 3.1952 - val_y2_output_root_mean_squared_error: 3.9318
# Epoch 8/500
# 614/614 [==============================] - 0s 143us/sample - loss: 23.8448 - y1_output_loss: 9.0298 - y2_output_loss: 14.7476 - y1_output_root_mean_squared_error: 3.0177 - y2_output_root_mean_squared_error: 3.8391 - val_loss: 21.0536 - val_y1_output_loss: 8.5682 - val_y2_output_loss: 13.3176 - val_y1_output_root_mean_squared_error: 2.9180 - val_y2_output_root_mean_squared_error: 3.5410
# Epoch 9/500
# 614/614 [==============================] - 0s 151us/sample - loss: 21.2827 - y1_output_loss: 7.9803 - y2_output_loss: 13.1957 - y1_output_root_mean_squared_error: 2.8374 - y2_output_root_mean_squared_error: 3.6375 - val_loss: 21.3984 - val_y1_output_loss: 8.5086 - val_y2_output_loss: 13.5427 - val_y1_output_root_mean_squared_error: 2.8973 - val_y2_output_root_mean_squared_error: 3.6061
# Epoch 10/500
# 614/614 [==============================] - 0s 146us/sample - loss: 20.3040 - y1_output_loss: 8.3902 - y2_output_loss: 12.0382 - y1_output_root_mean_squared_error: 2.8930 - y2_output_root_mean_squared_error: 3.4546 - val_loss: 38.1185 - val_y1_output_loss: 9.7771 - val_y2_output_loss: 28.4097 - val_y1_output_root_mean_squared_error: 3.1142 - val_y2_output_root_mean_squared_error: 5.3311
# Epoch 11/500
# 614/614 [==============================] - 0s 146us/sample - loss: 24.0284 - y1_output_loss: 8.6784 - y2_output_loss: 15.1472 - y1_output_root_mean_squared_error: 2.9569 - y2_output_root_mean_squared_error: 3.9096 - val_loss: 19.5293 - val_y1_output_loss: 8.5392 - val_y2_output_loss: 11.5163 - val_y1_output_root_mean_squared_error: 2.9185 - val_y2_output_root_mean_squared_error: 3.3184
# Epoch 12/500
# 614/614 [==============================] - 0s 145us/sample - loss: 18.9789 - y1_output_loss: 7.7839 - y2_output_loss: 11.0852 - y1_output_root_mean_squared_error: 2.7951 - y2_output_root_mean_squared_error: 3.3416 - val_loss: 19.9902 - val_y1_output_loss: 9.1577 - val_y2_output_loss: 11.5568 - val_y1_output_root_mean_squared_error: 3.0013 - val_y2_output_root_mean_squared_error: 3.3139
# Epoch 13/500
# 614/614 [==============================] - 0s 155us/sample - loss: 21.1343 - y1_output_loss: 8.0339 - y2_output_loss: 13.2073 - y1_output_root_mean_squared_error: 2.8362 - y2_output_root_mean_squared_error: 3.6180 - val_loss: 19.6379 - val_y1_output_loss: 8.5158 - val_y2_output_loss: 12.2321 - val_y1_output_root_mean_squared_error: 2.8801 - val_y2_output_root_mean_squared_error: 3.3680
# Epoch 14/500
# 614/614 [==============================] - 0s 147us/sample - loss: 17.7655 - y1_output_loss: 6.9894 - y2_output_loss: 10.6202 - y1_output_root_mean_squared_error: 2.6563 - y2_output_root_mean_squared_error: 3.2725 - val_loss: 18.9088 - val_y1_output_loss: 8.4044 - val_y2_output_loss: 11.9214 - val_y1_output_root_mean_squared_error: 2.8409 - val_y2_output_root_mean_squared_error: 3.2921
# Epoch 15/500
# 614/614 [==============================] - 0s 148us/sample - loss: 19.6513 - y1_output_loss: 7.4525 - y2_output_loss: 12.2357 - y1_output_root_mean_squared_error: 2.7386 - y2_output_root_mean_squared_error: 3.4859 - val_loss: 25.9458 - val_y1_output_loss: 9.3200 - val_y2_output_loss: 18.5423 - val_y1_output_root_mean_squared_error: 2.9882 - val_y2_output_root_mean_squared_error: 4.1251
# Epoch 16/500
# 614/614 [==============================] - 0s 148us/sample - loss: 16.9497 - y1_output_loss: 6.6237 - y2_output_loss: 10.1993 - y1_output_root_mean_squared_error: 2.5829 - y2_output_root_mean_squared_error: 3.2060 - val_loss: 17.8644 - val_y1_output_loss: 7.4716 - val_y2_output_loss: 11.1091 - val_y1_output_root_mean_squared_error: 2.7089 - val_y2_output_root_mean_squared_error: 3.2444
# Epoch 17/500
# 614/614 [==============================] - 0s 141us/sample - loss: 17.5652 - y1_output_loss: 6.7000 - y2_output_loss: 10.9249 - y1_output_root_mean_squared_error: 2.5866 - y2_output_root_mean_squared_error: 3.2977 - val_loss: 22.4792 - val_y1_output_loss: 9.3813 - val_y2_output_loss: 14.1372 - val_y1_output_root_mean_squared_error: 3.0375 - val_y2_output_root_mean_squared_error: 3.6404
# Epoch 18/500
# 614/614 [==============================] - 0s 146us/sample - loss: 17.2812 - y1_output_loss: 6.4032 - y2_output_loss: 10.8918 - y1_output_root_mean_squared_error: 2.5400 - y2_output_root_mean_squared_error: 3.2909 - val_loss: 23.1168 - val_y1_output_loss: 7.6950 - val_y2_output_loss: 16.7928 - val_y1_output_root_mean_squared_error: 2.7486 - val_y2_output_root_mean_squared_error: 3.9449
# Epoch 19/500
# 614/614 [==============================] - 0s 143us/sample - loss: 15.4571 - y1_output_loss: 6.1120 - y2_output_loss: 9.4142 - y1_output_root_mean_squared_error: 2.4617 - y2_output_root_mean_squared_error: 3.0655 - val_loss: 15.2077 - val_y1_output_loss: 6.3175 - val_y2_output_loss: 9.6383 - val_y1_output_root_mean_squared_error: 2.5048 - val_y2_output_root_mean_squared_error: 2.9889
# Epoch 20/500
# 614/614 [==============================] - 0s 147us/sample - loss: 14.5212 - y1_output_loss: 5.7607 - y2_output_loss: 8.6521 - y1_output_root_mean_squared_error: 2.4097 - y2_output_root_mean_squared_error: 2.9521 - val_loss: 14.9708 - val_y1_output_loss: 5.8789 - val_y2_output_loss: 9.3275 - val_y1_output_root_mean_squared_error: 2.4240 - val_y2_output_root_mean_squared_error: 3.0158
# Epoch 21/500
# 614/614 [==============================] - 0s 146us/sample - loss: 13.7982 - y1_output_loss: 5.5040 - y2_output_loss: 8.2568 - y1_output_root_mean_squared_error: 2.3543 - y2_output_root_mean_squared_error: 2.8732 - val_loss: 23.5782 - val_y1_output_loss: 7.2792 - val_y2_output_loss: 15.8292 - val_y1_output_root_mean_squared_error: 2.7295 - val_y2_output_root_mean_squared_error: 4.0160
# Epoch 22/500
# 614/614 [==============================] - 0s 154us/sample - loss: 15.4933 - y1_output_loss: 5.7103 - y2_output_loss: 9.8361 - y1_output_root_mean_squared_error: 2.3969 - y2_output_root_mean_squared_error: 3.1222 - val_loss: 38.0937 - val_y1_output_loss: 8.2098 - val_y2_output_loss: 28.9635 - val_y1_output_root_mean_squared_error: 2.9117 - val_y2_output_root_mean_squared_error: 5.4420
# Epoch 23/500
# 614/614 [==============================] - 0s 147us/sample - loss: 19.2977 - y1_output_loss: 6.7126 - y2_output_loss: 12.4334 - y1_output_root_mean_squared_error: 2.6020 - y2_output_root_mean_squared_error: 3.5394 - val_loss: 14.1286 - val_y1_output_loss: 5.9219 - val_y2_output_loss: 8.3745 - val_y1_output_root_mean_squared_error: 2.4389 - val_y2_output_root_mean_squared_error: 2.8602
# Epoch 24/500
# 614/614 [==============================] - 0s 148us/sample - loss: 17.6970 - y1_output_loss: 6.1309 - y2_output_loss: 11.4394 - y1_output_root_mean_squared_error: 2.4856 - y2_output_root_mean_squared_error: 3.3939 - val_loss: 13.8713 - val_y1_output_loss: 5.2594 - val_y2_output_loss: 8.7482 - val_y1_output_root_mean_squared_error: 2.2928 - val_y2_output_root_mean_squared_error: 2.9350
# Epoch 25/500
# 614/614 [==============================] - 0s 150us/sample - loss: 14.2821 - y1_output_loss: 5.3257 - y2_output_loss: 8.9054 - y1_output_root_mean_squared_error: 2.3173 - y2_output_root_mean_squared_error: 2.9853 - val_loss: 13.4368 - val_y1_output_loss: 5.2084 - val_y2_output_loss: 8.5426 - val_y1_output_root_mean_squared_error: 2.2709 - val_y2_output_root_mean_squared_error: 2.8775
# Epoch 26/500
# 614/614 [==============================] - 0s 147us/sample - loss: 12.4951 - y1_output_loss: 4.9500 - y2_output_loss: 7.6247 - y1_output_root_mean_squared_error: 2.2220 - y2_output_root_mean_squared_error: 2.7491 - val_loss: 18.4365 - val_y1_output_loss: 5.8424 - val_y2_output_loss: 13.7370 - val_y1_output_root_mean_squared_error: 2.3891 - val_y2_output_root_mean_squared_error: 3.5678
# Epoch 27/500
# 614/614 [==============================] - 0s 152us/sample - loss: 12.8257 - y1_output_loss: 5.0106 - y2_output_loss: 7.9602 - y1_output_root_mean_squared_error: 2.2266 - y2_output_root_mean_squared_error: 2.8050 - val_loss: 15.7012 - val_y1_output_loss: 7.0509 - val_y2_output_loss: 9.9928 - val_y1_output_root_mean_squared_error: 2.5894 - val_y2_output_root_mean_squared_error: 2.9994
# Epoch 28/500
# 614/614 [==============================] - 0s 143us/sample - loss: 12.4101 - y1_output_loss: 4.7354 - y2_output_loss: 7.8979 - y1_output_root_mean_squared_error: 2.1695 - y2_output_root_mean_squared_error: 2.7755 - val_loss: 33.2146 - val_y1_output_loss: 7.1650 - val_y2_output_loss: 25.2348 - val_y1_output_root_mean_squared_error: 2.7161 - val_y2_output_root_mean_squared_error: 5.0831
# Epoch 29/500
# 614/614 [==============================] - 0s 163us/sample - loss: 14.8145 - y1_output_loss: 5.0699 - y2_output_loss: 9.7296 - y1_output_root_mean_squared_error: 2.2554 - y2_output_root_mean_squared_error: 3.1189 - val_loss: 17.6196 - val_y1_output_loss: 5.7368 - val_y2_output_loss: 11.4200 - val_y1_output_root_mean_squared_error: 2.4303 - val_y2_output_root_mean_squared_error: 3.4225
# Epoch 30/500
# 614/614 [==============================] - 0s 144us/sample - loss: 13.4078 - y1_output_loss: 5.2257 - y2_output_loss: 8.3863 - y1_output_root_mean_squared_error: 2.2682 - y2_output_root_mean_squared_error: 2.8745 - val_loss: 30.6024 - val_y1_output_loss: 7.9256 - val_y2_output_loss: 21.7476 - val_y1_output_root_mean_squared_error: 2.8641 - val_y2_output_root_mean_squared_error: 4.7328
# Epoch 31/500
# 614/614 [==============================] - 0s 139us/sample - loss: 12.7887 - y1_output_loss: 4.6549 - y2_output_loss: 8.3226 - y1_output_root_mean_squared_error: 2.1562 - y2_output_root_mean_squared_error: 2.8530 - val_loss: 39.1065 - val_y1_output_loss: 7.5522 - val_y2_output_loss: 30.8962 - val_y1_output_root_mean_squared_error: 2.7747 - val_y2_output_root_mean_squared_error: 5.6043
# Epoch 32/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.8555 - y1_output_loss: 4.3712 - y2_output_loss: 8.6973 - y1_output_root_mean_squared_error: 2.0874 - y2_output_root_mean_squared_error: 2.9152 - val_loss: 48.8932 - val_y1_output_loss: 9.1287 - val_y2_output_loss: 39.5092 - val_y1_output_root_mean_squared_error: 3.0192 - val_y2_output_root_mean_squared_error: 6.3070
# Epoch 33/500
# 614/614 [==============================] - 0s 145us/sample - loss: 13.9161 - y1_output_loss: 4.5720 - y2_output_loss: 9.4260 - y1_output_root_mean_squared_error: 2.1440 - y2_output_root_mean_squared_error: 3.0527 - val_loss: 43.1396 - val_y1_output_loss: 8.7854 - val_y2_output_loss: 33.9547 - val_y1_output_root_mean_squared_error: 2.9711 - val_y2_output_root_mean_squared_error: 5.8577
# Epoch 34/500
# 614/614 [==============================] - 0s 148us/sample - loss: 11.9442 - y1_output_loss: 4.2736 - y2_output_loss: 7.7166 - y1_output_root_mean_squared_error: 2.0680 - y2_output_root_mean_squared_error: 2.7691 - val_loss: 13.4254 - val_y1_output_loss: 4.8423 - val_y2_output_loss: 9.4082 - val_y1_output_root_mean_squared_error: 2.1755 - val_y2_output_root_mean_squared_error: 2.9483
# Epoch 35/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.0724 - y1_output_loss: 4.2117 - y2_output_loss: 7.8821 - y1_output_root_mean_squared_error: 2.0549 - y2_output_root_mean_squared_error: 2.8017 - val_loss: 20.9507 - val_y1_output_loss: 4.9455 - val_y2_output_loss: 15.8334 - val_y1_output_root_mean_squared_error: 2.2252 - val_y2_output_root_mean_squared_error: 3.9999
# Epoch 36/500
# 614/614 [==============================] - 0s 159us/sample - loss: 10.5046 - y1_output_loss: 3.6894 - y2_output_loss: 6.7309 - y1_output_root_mean_squared_error: 1.9275 - y2_output_root_mean_squared_error: 2.6056 - val_loss: 9.5364 - val_y1_output_loss: 3.6205 - val_y2_output_loss: 5.9191 - val_y1_output_root_mean_squared_error: 1.9207 - val_y2_output_root_mean_squared_error: 2.4181
# Epoch 37/500
# 614/614 [==============================] - 0s 145us/sample - loss: 11.0416 - y1_output_loss: 3.7901 - y2_output_loss: 7.1675 - y1_output_root_mean_squared_error: 1.9541 - y2_output_root_mean_squared_error: 2.6876 - val_loss: 9.2288 - val_y1_output_loss: 3.8360 - val_y2_output_loss: 5.9881 - val_y1_output_root_mean_squared_error: 1.9233 - val_y2_output_root_mean_squared_error: 2.3515
# Epoch 38/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.3994 - y1_output_loss: 3.5932 - y2_output_loss: 6.7171 - y1_output_root_mean_squared_error: 1.9037 - y2_output_root_mean_squared_error: 2.6030 - val_loss: 9.3195 - val_y1_output_loss: 3.4448 - val_y2_output_loss: 6.0215 - val_y1_output_root_mean_squared_error: 1.8546 - val_y2_output_root_mean_squared_error: 2.4249
# Epoch 39/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.0266 - y1_output_loss: 4.1535 - y2_output_loss: 7.8502 - y1_output_root_mean_squared_error: 2.0280 - y2_output_root_mean_squared_error: 2.8131 - val_loss: 10.8452 - val_y1_output_loss: 4.0882 - val_y2_output_loss: 7.6313 - val_y1_output_root_mean_squared_error: 1.9787 - val_y2_output_root_mean_squared_error: 2.6325
# Epoch 40/500
# 614/614 [==============================] - 0s 153us/sample - loss: 11.2774 - y1_output_loss: 3.5873 - y2_output_loss: 7.6084 - y1_output_root_mean_squared_error: 1.9030 - y2_output_root_mean_squared_error: 2.7670 - val_loss: 10.2110 - val_y1_output_loss: 3.2653 - val_y2_output_loss: 7.6913 - val_y1_output_root_mean_squared_error: 1.7901 - val_y2_output_root_mean_squared_error: 2.6470
# Epoch 41/500
# 614/614 [==============================] - 0s 148us/sample - loss: 10.1407 - y1_output_loss: 3.2295 - y2_output_loss: 6.8821 - y1_output_root_mean_squared_error: 1.8034 - y2_output_root_mean_squared_error: 2.6246 - val_loss: 11.9435 - val_y1_output_loss: 3.2417 - val_y2_output_loss: 8.4827 - val_y1_output_root_mean_squared_error: 1.8178 - val_y2_output_root_mean_squared_error: 2.9392
# Epoch 42/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.5388 - y1_output_loss: 3.1431 - y2_output_loss: 5.4753 - y1_output_root_mean_squared_error: 1.7531 - y2_output_root_mean_squared_error: 2.3378 - val_loss: 14.9931 - val_y1_output_loss: 4.9581 - val_y2_output_loss: 10.8227 - val_y1_output_root_mean_squared_error: 2.2034 - val_y2_output_root_mean_squared_error: 3.1841
# Epoch 43/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.7458 - y1_output_loss: 2.9332 - y2_output_loss: 5.7453 - y1_output_root_mean_squared_error: 1.7206 - y2_output_root_mean_squared_error: 2.4053 - val_loss: 10.1445 - val_y1_output_loss: 3.5369 - val_y2_output_loss: 7.1688 - val_y1_output_root_mean_squared_error: 1.8630 - val_y2_output_root_mean_squared_error: 2.5834
# Epoch 44/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.5009 - y1_output_loss: 2.8389 - y2_output_loss: 5.6200 - y1_output_root_mean_squared_error: 1.6870 - y2_output_root_mean_squared_error: 2.3780 - val_loss: 7.6333 - val_y1_output_loss: 2.8074 - val_y2_output_loss: 5.1066 - val_y1_output_root_mean_squared_error: 1.6751 - val_y2_output_root_mean_squared_error: 2.1972
# Epoch 45/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.0162 - y1_output_loss: 2.4594 - y2_output_loss: 4.5836 - y1_output_root_mean_squared_error: 1.5663 - y2_output_root_mean_squared_error: 2.1361 - val_loss: 11.0817 - val_y1_output_loss: 4.4002 - val_y2_output_loss: 6.6973 - val_y1_output_root_mean_squared_error: 2.0915 - val_y2_output_root_mean_squared_error: 2.5898
# Epoch 46/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.3946 - y1_output_loss: 2.7208 - y2_output_loss: 5.6112 - y1_output_root_mean_squared_error: 1.6551 - y2_output_root_mean_squared_error: 2.3781 - val_loss: 12.3877 - val_y1_output_loss: 3.8707 - val_y2_output_loss: 8.1744 - val_y1_output_root_mean_squared_error: 1.9994 - val_y2_output_root_mean_squared_error: 2.8966
# Epoch 47/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.5443 - y1_output_loss: 2.4983 - y2_output_loss: 5.9973 - y1_output_root_mean_squared_error: 1.5799 - y2_output_root_mean_squared_error: 2.4593 - val_loss: 7.4492 - val_y1_output_loss: 2.7544 - val_y2_output_loss: 4.8170 - val_y1_output_root_mean_squared_error: 1.6682 - val_y2_output_root_mean_squared_error: 2.1601
# Epoch 48/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.9446 - y1_output_loss: 2.5077 - y2_output_loss: 5.4005 - y1_output_root_mean_squared_error: 1.5867 - y2_output_root_mean_squared_error: 2.3296 - val_loss: 8.0558 - val_y1_output_loss: 2.4608 - val_y2_output_loss: 5.7166 - val_y1_output_root_mean_squared_error: 1.5852 - val_y2_output_root_mean_squared_error: 2.3544
# Epoch 49/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.1175 - y1_output_loss: 2.4501 - y2_output_loss: 4.6308 - y1_output_root_mean_squared_error: 1.5639 - y2_output_root_mean_squared_error: 2.1614 - val_loss: 7.0039 - val_y1_output_loss: 2.4049 - val_y2_output_loss: 4.6751 - val_y1_output_root_mean_squared_error: 1.5670 - val_y2_output_root_mean_squared_error: 2.1327
# Epoch 50/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.1849 - y1_output_loss: 2.3879 - y2_output_loss: 4.7792 - y1_output_root_mean_squared_error: 1.5404 - y2_output_root_mean_squared_error: 2.1937 - val_loss: 7.9854 - val_y1_output_loss: 2.6013 - val_y2_output_loss: 5.6006 - val_y1_output_root_mean_squared_error: 1.6303 - val_y2_output_root_mean_squared_error: 2.3082
# Epoch 51/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.2236 - y1_output_loss: 2.4067 - y2_output_loss: 4.8366 - y1_output_root_mean_squared_error: 1.5354 - y2_output_root_mean_squared_error: 2.2059 - val_loss: 8.3470 - val_y1_output_loss: 3.0562 - val_y2_output_loss: 5.2638 - val_y1_output_root_mean_squared_error: 1.7482 - val_y2_output_root_mean_squared_error: 2.3002
# Epoch 52/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.8132 - y1_output_loss: 2.5012 - y2_output_loss: 5.3752 - y1_output_root_mean_squared_error: 1.5855 - y2_output_root_mean_squared_error: 2.3020 - val_loss: 34.6766 - val_y1_output_loss: 6.8915 - val_y2_output_loss: 27.2265 - val_y1_output_root_mean_squared_error: 2.6431 - val_y2_output_root_mean_squared_error: 5.2622
# Epoch 53/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.2819 - y1_output_loss: 2.7657 - y2_output_loss: 6.4817 - y1_output_root_mean_squared_error: 1.6650 - y2_output_root_mean_squared_error: 2.5514 - val_loss: 22.2125 - val_y1_output_loss: 7.7442 - val_y2_output_loss: 16.3917 - val_y1_output_root_mean_squared_error: 2.6861 - val_y2_output_root_mean_squared_error: 3.8727
# Epoch 54/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.0374 - y1_output_loss: 2.2780 - y2_output_loss: 4.7031 - y1_output_root_mean_squared_error: 1.5158 - y2_output_root_mean_squared_error: 2.1771 - val_loss: 11.5341 - val_y1_output_loss: 3.2728 - val_y2_output_loss: 7.9693 - val_y1_output_root_mean_squared_error: 1.8356 - val_y2_output_root_mean_squared_error: 2.8574
# Epoch 55/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.8965 - y1_output_loss: 2.0725 - y2_output_loss: 4.8698 - y1_output_root_mean_squared_error: 1.4409 - y2_output_root_mean_squared_error: 2.1955 - val_loss: 14.1531 - val_y1_output_loss: 3.4155 - val_y2_output_loss: 10.7421 - val_y1_output_root_mean_squared_error: 1.8341 - val_y2_output_root_mean_squared_error: 3.2847
# Epoch 56/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.0711 - y1_output_loss: 2.5035 - y2_output_loss: 5.5004 - y1_output_root_mean_squared_error: 1.5879 - y2_output_root_mean_squared_error: 2.3558 - val_loss: 6.4573 - val_y1_output_loss: 2.1049 - val_y2_output_loss: 4.4171 - val_y1_output_root_mean_squared_error: 1.4661 - val_y2_output_root_mean_squared_error: 2.0755
# Epoch 57/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.9612 - y1_output_loss: 1.9373 - y2_output_loss: 4.0616 - y1_output_root_mean_squared_error: 1.3945 - y2_output_root_mean_squared_error: 2.0041 - val_loss: 17.5481 - val_y1_output_loss: 3.7063 - val_y2_output_loss: 13.4122 - val_y1_output_root_mean_squared_error: 1.9468 - val_y2_output_root_mean_squared_error: 3.7092
# Epoch 58/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.7703 - y1_output_loss: 1.9293 - y2_output_loss: 4.7968 - y1_output_root_mean_squared_error: 1.3898 - y2_output_root_mean_squared_error: 2.1997 - val_loss: 7.1629 - val_y1_output_loss: 2.4354 - val_y2_output_loss: 4.5813 - val_y1_output_root_mean_squared_error: 1.5875 - val_y2_output_root_mean_squared_error: 2.1547
# Epoch 59/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.4337 - y1_output_loss: 2.0014 - y2_output_loss: 4.4034 - y1_output_root_mean_squared_error: 1.4150 - y2_output_root_mean_squared_error: 2.1051 - val_loss: 8.5441 - val_y1_output_loss: 2.2857 - val_y2_output_loss: 6.6165 - val_y1_output_root_mean_squared_error: 1.5190 - val_y2_output_root_mean_squared_error: 2.4974
# Epoch 60/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1903 - y1_output_loss: 1.9616 - y2_output_loss: 4.3825 - y1_output_root_mean_squared_error: 1.3851 - y2_output_root_mean_squared_error: 2.0668 - val_loss: 16.6885 - val_y1_output_loss: 4.8300 - val_y2_output_loss: 12.4187 - val_y1_output_root_mean_squared_error: 2.1968 - val_y2_output_root_mean_squared_error: 3.4442
# Epoch 61/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.5775 - y1_output_loss: 2.0618 - y2_output_loss: 4.5263 - y1_output_root_mean_squared_error: 1.4426 - y2_output_root_mean_squared_error: 2.1205 - val_loss: 8.3370 - val_y1_output_loss: 2.4135 - val_y2_output_loss: 5.7464 - val_y1_output_root_mean_squared_error: 1.5629 - val_y2_output_root_mean_squared_error: 2.4278
# Epoch 62/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.8328 - y1_output_loss: 2.0237 - y2_output_loss: 4.8273 - y1_output_root_mean_squared_error: 1.4205 - y2_output_root_mean_squared_error: 2.1943 - val_loss: 9.2709 - val_y1_output_loss: 2.5140 - val_y2_output_loss: 6.4957 - val_y1_output_root_mean_squared_error: 1.6134 - val_y2_output_root_mean_squared_error: 2.5822
# Epoch 63/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.1263 - y1_output_loss: 1.8475 - y2_output_loss: 4.2765 - y1_output_root_mean_squared_error: 1.3615 - y2_output_root_mean_squared_error: 2.0670 - val_loss: 19.1537 - val_y1_output_loss: 3.5296 - val_y2_output_loss: 15.2943 - val_y1_output_root_mean_squared_error: 1.8882 - val_y2_output_root_mean_squared_error: 3.9482
# Epoch 64/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.7789 - y1_output_loss: 1.8666 - y2_output_loss: 4.8811 - y1_output_root_mean_squared_error: 1.3724 - y2_output_root_mean_squared_error: 2.2126 - val_loss: 6.7882 - val_y1_output_loss: 1.8306 - val_y2_output_loss: 4.7620 - val_y1_output_root_mean_squared_error: 1.3766 - val_y2_output_root_mean_squared_error: 2.2120
# Epoch 65/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.8942 - y1_output_loss: 2.2188 - y2_output_loss: 5.6407 - y1_output_root_mean_squared_error: 1.4893 - y2_output_root_mean_squared_error: 2.3825 - val_loss: 7.2435 - val_y1_output_loss: 2.1799 - val_y2_output_loss: 4.9700 - val_y1_output_root_mean_squared_error: 1.4921 - val_y2_output_root_mean_squared_error: 2.2399
# Epoch 66/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.8842 - y1_output_loss: 2.1350 - y2_output_loss: 4.6935 - y1_output_root_mean_squared_error: 1.4651 - y2_output_root_mean_squared_error: 2.1766 - val_loss: 5.8864 - val_y1_output_loss: 1.7814 - val_y2_output_loss: 4.0787 - val_y1_output_root_mean_squared_error: 1.3461 - val_y2_output_root_mean_squared_error: 2.0185
# Epoch 67/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.2531 - y1_output_loss: 2.6599 - y2_output_loss: 6.5455 - y1_output_root_mean_squared_error: 1.6301 - y2_output_root_mean_squared_error: 2.5682 - val_loss: 9.1410 - val_y1_output_loss: 2.2828 - val_y2_output_loss: 7.1902 - val_y1_output_root_mean_squared_error: 1.5223 - val_y2_output_root_mean_squared_error: 2.6122
# Epoch 68/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.3116 - y1_output_loss: 1.6923 - y2_output_loss: 3.6194 - y1_output_root_mean_squared_error: 1.2946 - y2_output_root_mean_squared_error: 1.9067 - val_loss: 7.4078 - val_y1_output_loss: 2.6109 - val_y2_output_loss: 4.8243 - val_y1_output_root_mean_squared_error: 1.6176 - val_y2_output_root_mean_squared_error: 2.1888
# Epoch 69/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.0286 - y1_output_loss: 1.4607 - y2_output_loss: 3.5490 - y1_output_root_mean_squared_error: 1.2134 - y2_output_root_mean_squared_error: 1.8858 - val_loss: 5.7289 - val_y1_output_loss: 1.7978 - val_y2_output_loss: 3.9899 - val_y1_output_root_mean_squared_error: 1.3512 - val_y2_output_root_mean_squared_error: 1.9756
# Epoch 70/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.1779 - y1_output_loss: 1.5859 - y2_output_loss: 3.5930 - y1_output_root_mean_squared_error: 1.2637 - y2_output_root_mean_squared_error: 1.8924 - val_loss: 11.5558 - val_y1_output_loss: 2.0837 - val_y2_output_loss: 9.1078 - val_y1_output_root_mean_squared_error: 1.4659 - val_y2_output_root_mean_squared_error: 3.0671
# Epoch 71/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.6720 - y1_output_loss: 1.7730 - y2_output_loss: 3.8471 - y1_output_root_mean_squared_error: 1.3376 - y2_output_root_mean_squared_error: 1.9705 - val_loss: 4.9513 - val_y1_output_loss: 1.4810 - val_y2_output_loss: 3.5652 - val_y1_output_root_mean_squared_error: 1.2309 - val_y2_output_root_mean_squared_error: 1.8537
# Epoch 72/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.2866 - y1_output_loss: 1.5953 - y2_output_loss: 3.6751 - y1_output_root_mean_squared_error: 1.2683 - y2_output_root_mean_squared_error: 1.9178 - val_loss: 5.3293 - val_y1_output_loss: 1.6334 - val_y2_output_loss: 3.7277 - val_y1_output_root_mean_squared_error: 1.2912 - val_y2_output_root_mean_squared_error: 1.9136
# Epoch 73/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.1360 - y1_output_loss: 1.5206 - y2_output_loss: 3.5772 - y1_output_root_mean_squared_error: 1.2362 - y2_output_root_mean_squared_error: 1.8994 - val_loss: 5.9641 - val_y1_output_loss: 1.7256 - val_y2_output_loss: 4.4205 - val_y1_output_root_mean_squared_error: 1.3256 - val_y2_output_root_mean_squared_error: 2.0511
# Epoch 74/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.1364 - y1_output_loss: 1.5444 - y2_output_loss: 3.5635 - y1_output_root_mean_squared_error: 1.2459 - y2_output_root_mean_squared_error: 1.8932 - val_loss: 6.4275 - val_y1_output_loss: 2.0166 - val_y2_output_loss: 4.4147 - val_y1_output_root_mean_squared_error: 1.4350 - val_y2_output_root_mean_squared_error: 2.0901
# Epoch 75/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.2672 - y1_output_loss: 1.9559 - y2_output_loss: 4.2513 - y1_output_root_mean_squared_error: 1.4053 - y2_output_root_mean_squared_error: 2.0718 - val_loss: 6.2509 - val_y1_output_loss: 2.1402 - val_y2_output_loss: 4.1476 - val_y1_output_root_mean_squared_error: 1.4482 - val_y2_output_root_mean_squared_error: 2.0381
# Epoch 76/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.2066 - y1_output_loss: 1.3656 - y2_output_loss: 3.8588 - y1_output_root_mean_squared_error: 1.1687 - y2_output_root_mean_squared_error: 1.9598 - val_loss: 20.5275 - val_y1_output_loss: 6.3496 - val_y2_output_loss: 14.7554 - val_y1_output_root_mean_squared_error: 2.4476 - val_y2_output_root_mean_squared_error: 3.8127
# Epoch 77/500
# 614/614 [==============================] - 0s 148us/sample - loss: 13.1294 - y1_output_loss: 4.9802 - y2_output_loss: 8.0995 - y1_output_root_mean_squared_error: 2.2400 - y2_output_root_mean_squared_error: 2.8481 - val_loss: 16.7747 - val_y1_output_loss: 3.2051 - val_y2_output_loss: 13.1419 - val_y1_output_root_mean_squared_error: 1.8103 - val_y2_output_root_mean_squared_error: 3.6739
# Epoch 78/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.9491 - y1_output_loss: 1.3683 - y2_output_loss: 3.6064 - y1_output_root_mean_squared_error: 1.1736 - y2_output_root_mean_squared_error: 1.8899 - val_loss: 8.2260 - val_y1_output_loss: 2.1265 - val_y2_output_loss: 5.9414 - val_y1_output_root_mean_squared_error: 1.4627 - val_y2_output_root_mean_squared_error: 2.4671
# Epoch 79/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.4130 - y1_output_loss: 1.3453 - y2_output_loss: 3.0418 - y1_output_root_mean_squared_error: 1.1595 - y2_output_root_mean_squared_error: 1.7518 - val_loss: 4.7842 - val_y1_output_loss: 1.4506 - val_y2_output_loss: 3.5346 - val_y1_output_root_mean_squared_error: 1.2170 - val_y2_output_root_mean_squared_error: 1.8175
# Epoch 80/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.9043 - y1_output_loss: 1.3328 - y2_output_loss: 3.5520 - y1_output_root_mean_squared_error: 1.1592 - y2_output_root_mean_squared_error: 1.8869 - val_loss: 7.9505 - val_y1_output_loss: 1.5598 - val_y2_output_loss: 6.2276 - val_y1_output_root_mean_squared_error: 1.2583 - val_y2_output_root_mean_squared_error: 2.5233
# Epoch 81/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.7722 - y1_output_loss: 1.5098 - y2_output_loss: 4.2651 - y1_output_root_mean_squared_error: 1.2289 - y2_output_root_mean_squared_error: 2.0645 - val_loss: 7.9327 - val_y1_output_loss: 1.7710 - val_y2_output_loss: 6.0553 - val_y1_output_root_mean_squared_error: 1.3281 - val_y2_output_root_mean_squared_error: 2.4837
# Epoch 82/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.4646 - y1_output_loss: 1.3500 - y2_output_loss: 3.1905 - y1_output_root_mean_squared_error: 1.1588 - y2_output_root_mean_squared_error: 1.7669 - val_loss: 13.6687 - val_y1_output_loss: 6.1112 - val_y2_output_loss: 9.2341 - val_y1_output_root_mean_squared_error: 2.3593 - val_y2_output_root_mean_squared_error: 2.8465
# Epoch 83/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.1194 - y1_output_loss: 1.1455 - y2_output_loss: 3.0420 - y1_output_root_mean_squared_error: 1.0607 - y2_output_root_mean_squared_error: 1.7304 - val_loss: 12.8911 - val_y1_output_loss: 2.9618 - val_y2_output_loss: 10.7077 - val_y1_output_root_mean_squared_error: 1.7027 - val_y2_output_root_mean_squared_error: 3.1610
# Epoch 84/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.3374 - y1_output_loss: 1.1278 - y2_output_loss: 3.2297 - y1_output_root_mean_squared_error: 1.0646 - y2_output_root_mean_squared_error: 1.7900 - val_loss: 4.5795 - val_y1_output_loss: 1.2272 - val_y2_output_loss: 3.3283 - val_y1_output_root_mean_squared_error: 1.1218 - val_y2_output_root_mean_squared_error: 1.8223
# Epoch 85/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.9247 - y1_output_loss: 1.1206 - y2_output_loss: 2.9093 - y1_output_root_mean_squared_error: 1.0474 - y2_output_root_mean_squared_error: 1.6816 - val_loss: 31.2746 - val_y1_output_loss: 12.5149 - val_y2_output_loss: 21.6494 - val_y1_output_root_mean_squared_error: 3.4048 - val_y2_output_root_mean_squared_error: 4.4364
# Epoch 86/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.9990 - y1_output_loss: 1.5514 - y2_output_loss: 3.4810 - y1_output_root_mean_squared_error: 1.2487 - y2_output_root_mean_squared_error: 1.8547 - val_loss: 4.0874 - val_y1_output_loss: 1.0975 - val_y2_output_loss: 3.2161 - val_y1_output_root_mean_squared_error: 1.0537 - val_y2_output_root_mean_squared_error: 1.7254
# Epoch 87/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.1845 - y1_output_loss: 1.0950 - y2_output_loss: 3.0650 - y1_output_root_mean_squared_error: 1.0505 - y2_output_root_mean_squared_error: 1.7552 - val_loss: 3.9411 - val_y1_output_loss: 1.0487 - val_y2_output_loss: 3.1652 - val_y1_output_root_mean_squared_error: 1.0211 - val_y2_output_root_mean_squared_error: 1.7024
# Epoch 88/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.2373 - y1_output_loss: 0.8654 - y2_output_loss: 2.3666 - y1_output_root_mean_squared_error: 0.9341 - y2_output_root_mean_squared_error: 1.5377 - val_loss: 4.7074 - val_y1_output_loss: 1.0455 - val_y2_output_loss: 3.6772 - val_y1_output_root_mean_squared_error: 1.0173 - val_y2_output_root_mean_squared_error: 1.9164
# Epoch 89/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.0205 - y1_output_loss: 1.1398 - y2_output_loss: 2.8480 - y1_output_root_mean_squared_error: 1.0722 - y2_output_root_mean_squared_error: 1.6944 - val_loss: 3.6988 - val_y1_output_loss: 1.0128 - val_y2_output_loss: 2.9188 - val_y1_output_root_mean_squared_error: 0.9979 - val_y2_output_root_mean_squared_error: 1.6441
# Epoch 90/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.3237 - y1_output_loss: 0.9793 - y2_output_loss: 3.3578 - y1_output_root_mean_squared_error: 0.9903 - y2_output_root_mean_squared_error: 1.8284 - val_loss: 6.4905 - val_y1_output_loss: 1.6573 - val_y2_output_loss: 5.2204 - val_y1_output_root_mean_squared_error: 1.2794 - val_y2_output_root_mean_squared_error: 2.2031
# Epoch 91/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.6968 - y1_output_loss: 0.9631 - y2_output_loss: 2.6991 - y1_output_root_mean_squared_error: 0.9858 - y2_output_root_mean_squared_error: 1.6507 - val_loss: 4.2048 - val_y1_output_loss: 1.0895 - val_y2_output_loss: 3.0689 - val_y1_output_root_mean_squared_error: 1.0548 - val_y2_output_root_mean_squared_error: 1.7585
# Epoch 92/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.7882 - y1_output_loss: 0.8519 - y2_output_loss: 2.9467 - y1_output_root_mean_squared_error: 0.9259 - y2_output_root_mean_squared_error: 1.7120 - val_loss: 6.5767 - val_y1_output_loss: 1.1295 - val_y2_output_loss: 5.3830 - val_y1_output_root_mean_squared_error: 1.0565 - val_y2_output_root_mean_squared_error: 2.3368
# Epoch 93/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.3555 - y1_output_loss: 0.8470 - y2_output_loss: 2.5362 - y1_output_root_mean_squared_error: 0.9207 - y2_output_root_mean_squared_error: 1.5836 - val_loss: 5.1316 - val_y1_output_loss: 1.1621 - val_y2_output_loss: 3.9422 - val_y1_output_root_mean_squared_error: 1.0855 - val_y2_output_root_mean_squared_error: 1.9883
# Epoch 94/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.1133 - y1_output_loss: 1.0068 - y2_output_loss: 3.0921 - y1_output_root_mean_squared_error: 1.0070 - y2_output_root_mean_squared_error: 1.7605 - val_loss: 3.8760 - val_y1_output_loss: 1.1411 - val_y2_output_loss: 2.7784 - val_y1_output_root_mean_squared_error: 1.0637 - val_y2_output_root_mean_squared_error: 1.6567
# Epoch 95/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.4829 - y1_output_loss: 1.2322 - y2_output_loss: 3.2583 - y1_output_root_mean_squared_error: 1.1097 - y2_output_root_mean_squared_error: 1.8032 - val_loss: 3.9471 - val_y1_output_loss: 1.0001 - val_y2_output_loss: 3.0981 - val_y1_output_root_mean_squared_error: 1.0131 - val_y2_output_root_mean_squared_error: 1.7090
# Epoch 96/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.6670 - y1_output_loss: 0.6262 - y2_output_loss: 2.0259 - y1_output_root_mean_squared_error: 0.7909 - y2_output_root_mean_squared_error: 1.4288 - val_loss: 3.2108 - val_y1_output_loss: 0.9665 - val_y2_output_loss: 2.3542 - val_y1_output_root_mean_squared_error: 0.9853 - val_y2_output_root_mean_squared_error: 1.4967
# Epoch 97/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.2156 - y1_output_loss: 0.8644 - y2_output_loss: 2.3586 - y1_output_root_mean_squared_error: 0.9268 - y2_output_root_mean_squared_error: 1.5351 - val_loss: 4.3712 - val_y1_output_loss: 1.2181 - val_y2_output_loss: 3.5426 - val_y1_output_root_mean_squared_error: 1.0818 - val_y2_output_root_mean_squared_error: 1.7891
# Epoch 98/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.6665 - y1_output_loss: 0.8023 - y2_output_loss: 2.8909 - y1_output_root_mean_squared_error: 0.8984 - y2_output_root_mean_squared_error: 1.6910 - val_loss: 8.2992 - val_y1_output_loss: 1.8804 - val_y2_output_loss: 6.3678 - val_y1_output_root_mean_squared_error: 1.3632 - val_y2_output_root_mean_squared_error: 2.5379
# Epoch 99/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.7510 - y1_output_loss: 0.9847 - y2_output_loss: 2.7555 - y1_output_root_mean_squared_error: 0.9938 - y2_output_root_mean_squared_error: 1.6623 - val_loss: 3.4484 - val_y1_output_loss: 0.8383 - val_y2_output_loss: 2.8968 - val_y1_output_root_mean_squared_error: 0.9022 - val_y2_output_root_mean_squared_error: 1.6231
# Epoch 100/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.0670 - y1_output_loss: 0.7049 - y2_output_loss: 2.3523 - y1_output_root_mean_squared_error: 0.8389 - y2_output_root_mean_squared_error: 1.5373 - val_loss: 4.0617 - val_y1_output_loss: 1.1133 - val_y2_output_loss: 2.9480 - val_y1_output_root_mean_squared_error: 1.0698 - val_y2_output_root_mean_squared_error: 1.7080
# Epoch 101/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.8727 - y1_output_loss: 0.7711 - y2_output_loss: 2.1385 - y1_output_root_mean_squared_error: 0.8779 - y2_output_root_mean_squared_error: 1.4498 - val_loss: 8.2990 - val_y1_output_loss: 1.0678 - val_y2_output_loss: 7.1035 - val_y1_output_root_mean_squared_error: 1.0378 - val_y2_output_root_mean_squared_error: 2.6874
# Epoch 102/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.7477 - y1_output_loss: 0.5874 - y2_output_loss: 2.1611 - y1_output_root_mean_squared_error: 0.7666 - y2_output_root_mean_squared_error: 1.4697 - val_loss: 6.8722 - val_y1_output_loss: 1.3553 - val_y2_output_loss: 5.4358 - val_y1_output_root_mean_squared_error: 1.1628 - val_y2_output_root_mean_squared_error: 2.3495
# Epoch 103/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.7452 - y1_output_loss: 0.6292 - y2_output_loss: 2.1268 - y1_output_root_mean_squared_error: 0.7901 - y2_output_root_mean_squared_error: 1.4564 - val_loss: 3.3862 - val_y1_output_loss: 0.7848 - val_y2_output_loss: 2.8181 - val_y1_output_root_mean_squared_error: 0.8904 - val_y2_output_root_mean_squared_error: 1.6104
# Epoch 104/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.9737 - y1_output_loss: 0.7205 - y2_output_loss: 2.2569 - y1_output_root_mean_squared_error: 0.8445 - y2_output_root_mean_squared_error: 1.5035 - val_loss: 6.6677 - val_y1_output_loss: 1.7524 - val_y2_output_loss: 5.6128 - val_y1_output_root_mean_squared_error: 1.2822 - val_y2_output_root_mean_squared_error: 2.2414
# Epoch 105/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.9382 - y1_output_loss: 0.6916 - y2_output_loss: 2.2317 - y1_output_root_mean_squared_error: 0.8347 - y2_output_root_mean_squared_error: 1.4972 - val_loss: 3.0125 - val_y1_output_loss: 0.8904 - val_y2_output_loss: 2.2056 - val_y1_output_root_mean_squared_error: 0.9434 - val_y2_output_root_mean_squared_error: 1.4569
# Epoch 106/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.7342 - y1_output_loss: 0.5817 - y2_output_loss: 2.1315 - y1_output_root_mean_squared_error: 0.7652 - y2_output_root_mean_squared_error: 1.4658 - val_loss: 2.8727 - val_y1_output_loss: 0.7372 - val_y2_output_loss: 2.2010 - val_y1_output_root_mean_squared_error: 0.8594 - val_y2_output_root_mean_squared_error: 1.4609
# Epoch 107/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.2762 - y1_output_loss: 0.6993 - y2_output_loss: 2.6267 - y1_output_root_mean_squared_error: 0.8337 - y2_output_root_mean_squared_error: 1.6066 - val_loss: 6.5673 - val_y1_output_loss: 1.4907 - val_y2_output_loss: 5.0375 - val_y1_output_root_mean_squared_error: 1.2170 - val_y2_output_root_mean_squared_error: 2.2553
# Epoch 108/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.0829 - y1_output_loss: 0.7334 - y2_output_loss: 2.3384 - y1_output_root_mean_squared_error: 0.8517 - y2_output_root_mean_squared_error: 1.5354 - val_loss: 3.2898 - val_y1_output_loss: 0.8965 - val_y2_output_loss: 2.4457 - val_y1_output_root_mean_squared_error: 0.9582 - val_y2_output_root_mean_squared_error: 1.5400
# Epoch 109/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.7337 - y1_output_loss: 0.5915 - y2_output_loss: 2.1558 - y1_output_root_mean_squared_error: 0.7654 - y2_output_root_mean_squared_error: 1.4656 - val_loss: 7.6018 - val_y1_output_loss: 3.3719 - val_y2_output_loss: 5.4055 - val_y1_output_root_mean_squared_error: 1.7361 - val_y2_output_root_mean_squared_error: 2.1419
# Epoch 110/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.9539 - y1_output_loss: 0.9221 - y2_output_loss: 3.0096 - y1_output_root_mean_squared_error: 0.9609 - y2_output_root_mean_squared_error: 1.7408 - val_loss: 3.6171 - val_y1_output_loss: 0.8362 - val_y2_output_loss: 2.9453 - val_y1_output_root_mean_squared_error: 0.9229 - val_y2_output_root_mean_squared_error: 1.6630
# Epoch 111/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.9331 - y1_output_loss: 0.6827 - y2_output_loss: 2.2741 - y1_output_root_mean_squared_error: 0.8176 - y2_output_root_mean_squared_error: 1.5049 - val_loss: 12.4298 - val_y1_output_loss: 3.7140 - val_y2_output_loss: 9.8020 - val_y1_output_root_mean_squared_error: 1.8639 - val_y2_output_root_mean_squared_error: 2.9926
# Epoch 112/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4585 - y1_output_loss: 0.8401 - y2_output_loss: 2.5920 - y1_output_root_mean_squared_error: 0.9200 - y2_output_root_mean_squared_error: 1.6162 - val_loss: 2.6449 - val_y1_output_loss: 0.6662 - val_y2_output_loss: 2.1675 - val_y1_output_root_mean_squared_error: 0.8225 - val_y2_output_root_mean_squared_error: 1.4030
# Epoch 113/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.7025 - y1_output_loss: 0.6579 - y2_output_loss: 2.0630 - y1_output_root_mean_squared_error: 0.8087 - y2_output_root_mean_squared_error: 1.4313 - val_loss: 7.1859 - val_y1_output_loss: 0.5494 - val_y2_output_loss: 6.9173 - val_y1_output_root_mean_squared_error: 0.7483 - val_y2_output_root_mean_squared_error: 2.5741
# Epoch 114/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.3177 - y1_output_loss: 0.5337 - y2_output_loss: 1.7727 - y1_output_root_mean_squared_error: 0.7323 - y2_output_root_mean_squared_error: 1.3347 - val_loss: 4.2925 - val_y1_output_loss: 1.2865 - val_y2_output_loss: 3.0459 - val_y1_output_root_mean_squared_error: 1.1148 - val_y2_output_root_mean_squared_error: 1.7463
# Epoch 115/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.5883 - y1_output_loss: 0.9248 - y2_output_loss: 2.6303 - y1_output_root_mean_squared_error: 0.9662 - y2_output_root_mean_squared_error: 1.6294 - val_loss: 2.7486 - val_y1_output_loss: 0.6971 - val_y2_output_loss: 2.2400 - val_y1_output_root_mean_squared_error: 0.8209 - val_y2_output_root_mean_squared_error: 1.4404
# Epoch 116/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.3454 - y1_output_loss: 0.5525 - y2_output_loss: 1.7973 - y1_output_root_mean_squared_error: 0.7362 - y2_output_root_mean_squared_error: 1.3429 - val_loss: 3.6958 - val_y1_output_loss: 1.0535 - val_y2_output_loss: 2.8052 - val_y1_output_root_mean_squared_error: 0.9978 - val_y2_output_root_mean_squared_error: 1.6432
# Epoch 117/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.1211 - y1_output_loss: 0.7595 - y2_output_loss: 2.3582 - y1_output_root_mean_squared_error: 0.8708 - y2_output_root_mean_squared_error: 1.5371 - val_loss: 2.9747 - val_y1_output_loss: 0.8305 - val_y2_output_loss: 2.2291 - val_y1_output_root_mean_squared_error: 0.9093 - val_y2_output_root_mean_squared_error: 1.4656
# Epoch 118/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.2404 - y1_output_loss: 0.4730 - y2_output_loss: 1.7513 - y1_output_root_mean_squared_error: 0.6887 - y2_output_root_mean_squared_error: 1.3290 - val_loss: 2.2789 - val_y1_output_loss: 0.4539 - val_y2_output_loss: 1.8411 - val_y1_output_root_mean_squared_error: 0.6799 - val_y2_output_root_mean_squared_error: 1.3478
# Epoch 119/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.0685 - y1_output_loss: 0.4157 - y2_output_loss: 1.6600 - y1_output_root_mean_squared_error: 0.6420 - y2_output_root_mean_squared_error: 1.2870 - val_loss: 2.6294 - val_y1_output_loss: 0.5287 - val_y2_output_loss: 2.3365 - val_y1_output_root_mean_squared_error: 0.7217 - val_y2_output_root_mean_squared_error: 1.4521
# Epoch 120/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5546 - y1_output_loss: 0.5642 - y2_output_loss: 1.9661 - y1_output_root_mean_squared_error: 0.7548 - y2_output_root_mean_squared_error: 1.4089 - val_loss: 2.3151 - val_y1_output_loss: 0.5059 - val_y2_output_loss: 1.8979 - val_y1_output_root_mean_squared_error: 0.7122 - val_y2_output_root_mean_squared_error: 1.3446
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3814 - y1_output_loss: 0.1186 - y2_output_loss: 0.2630 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.5119 - val_loss: 1.3426 - val_y1_output_loss: 0.2531 - val_y2_output_loss: 1.0752 - val_y1_output_root_mean_squared_error: 0.5020 - val_y2_output_root_mean_squared_error: 1.0443
# Epoch 462/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3751 - y1_output_loss: 0.1204 - y2_output_loss: 0.2565 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.5045 - val_loss: 0.7739 - val_y1_output_loss: 0.1611 - val_y2_output_loss: 0.5989 - val_y1_output_root_mean_squared_error: 0.4060 - val_y2_output_root_mean_squared_error: 0.7804
# Epoch 463/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4792 - y1_output_loss: 0.1388 - y2_output_loss: 0.3391 - y1_output_root_mean_squared_error: 0.3726 - y2_output_root_mean_squared_error: 0.5834 - val_loss: 0.7585 - val_y1_output_loss: 0.2118 - val_y2_output_loss: 0.5381 - val_y1_output_root_mean_squared_error: 0.4560 - val_y2_output_root_mean_squared_error: 0.7420
# Epoch 464/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3902 - y1_output_loss: 0.1251 - y2_output_loss: 0.2669 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.5147 - val_loss: 0.8114 - val_y1_output_loss: 0.2067 - val_y2_output_loss: 0.6080 - val_y1_output_root_mean_squared_error: 0.4553 - val_y2_output_root_mean_squared_error: 0.7773
# Epoch 465/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3969 - y1_output_loss: 0.1217 - y2_output_loss: 0.2775 - y1_output_root_mean_squared_error: 0.3464 - y2_output_root_mean_squared_error: 0.5262 - val_loss: 0.8943 - val_y1_output_loss: 0.3331 - val_y2_output_loss: 0.5705 - val_y1_output_root_mean_squared_error: 0.5624 - val_y2_output_root_mean_squared_error: 0.7603
# Epoch 466/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3339 - y1_output_loss: 0.1208 - y2_output_loss: 0.2119 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.4623 - val_loss: 0.7411 - val_y1_output_loss: 0.1947 - val_y2_output_loss: 0.5496 - val_y1_output_root_mean_squared_error: 0.4426 - val_y2_output_root_mean_squared_error: 0.7384
# Epoch 467/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4028 - y1_output_loss: 0.1156 - y2_output_loss: 0.2923 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.5354 - val_loss: 1.8223 - val_y1_output_loss: 0.1794 - val_y2_output_loss: 1.6664 - val_y1_output_root_mean_squared_error: 0.4268 - val_y2_output_root_mean_squared_error: 1.2807
# Epoch 468/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4101 - y1_output_loss: 0.1175 - y2_output_loss: 0.2918 - y1_output_root_mean_squared_error: 0.3430 - y2_output_root_mean_squared_error: 0.5408 - val_loss: 0.7261 - val_y1_output_loss: 0.1763 - val_y2_output_loss: 0.5412 - val_y1_output_root_mean_squared_error: 0.4256 - val_y2_output_root_mean_squared_error: 0.7382
# Epoch 469/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3525 - y1_output_loss: 0.1045 - y2_output_loss: 0.2512 - y1_output_root_mean_squared_error: 0.3164 - y2_output_root_mean_squared_error: 0.5024 - val_loss: 1.0748 - val_y1_output_loss: 0.3996 - val_y2_output_loss: 0.7293 - val_y1_output_root_mean_squared_error: 0.6173 - val_y2_output_root_mean_squared_error: 0.8329
# Epoch 470/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4995 - y1_output_loss: 0.1588 - y2_output_loss: 0.3375 - y1_output_root_mean_squared_error: 0.4000 - y2_output_root_mean_squared_error: 0.5827 - val_loss: 1.0740 - val_y1_output_loss: 0.2456 - val_y2_output_loss: 0.8433 - val_y1_output_root_mean_squared_error: 0.4950 - val_y2_output_root_mean_squared_error: 0.9104
# Epoch 471/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4110 - y1_output_loss: 0.1263 - y2_output_loss: 0.2835 - y1_output_root_mean_squared_error: 0.3556 - y2_output_root_mean_squared_error: 0.5334 - val_loss: 0.7378 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 0.5649 - val_y1_output_root_mean_squared_error: 0.4300 - val_y2_output_root_mean_squared_error: 0.7436
# Epoch 472/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3404 - y1_output_loss: 0.1086 - y2_output_loss: 0.2294 - y1_output_root_mean_squared_error: 0.3302 - y2_output_root_mean_squared_error: 0.4810 - val_loss: 0.6861 - val_y1_output_loss: 0.1751 - val_y2_output_loss: 0.5075 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.7129
# Epoch 473/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3469 - y1_output_loss: 0.1072 - y2_output_loss: 0.2378 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.4889 - val_loss: 1.1492 - val_y1_output_loss: 0.2529 - val_y2_output_loss: 0.9014 - val_y1_output_root_mean_squared_error: 0.5067 - val_y2_output_root_mean_squared_error: 0.9447
# Epoch 474/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3811 - y1_output_loss: 0.1266 - y2_output_loss: 0.2535 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.5042 - val_loss: 0.8938 - val_y1_output_loss: 0.2435 - val_y2_output_loss: 0.6331 - val_y1_output_root_mean_squared_error: 0.5003 - val_y2_output_root_mean_squared_error: 0.8022
# Epoch 475/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3378 - y1_output_loss: 0.1099 - y2_output_loss: 0.2275 - y1_output_root_mean_squared_error: 0.3324 - y2_output_root_mean_squared_error: 0.4768 - val_loss: 0.7815 - val_y1_output_loss: 0.1915 - val_y2_output_loss: 0.5834 - val_y1_output_root_mean_squared_error: 0.4446 - val_y2_output_root_mean_squared_error: 0.7641
# Epoch 476/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3692 - y1_output_loss: 0.1173 - y2_output_loss: 0.2506 - y1_output_root_mean_squared_error: 0.3440 - y2_output_root_mean_squared_error: 0.5009 - val_loss: 0.9876 - val_y1_output_loss: 0.1764 - val_y2_output_loss: 0.8162 - val_y1_output_root_mean_squared_error: 0.4239 - val_y2_output_root_mean_squared_error: 0.8989
# Epoch 477/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4586 - y1_output_loss: 0.1257 - y2_output_loss: 0.3311 - y1_output_root_mean_squared_error: 0.3553 - y2_output_root_mean_squared_error: 0.5765 - val_loss: 0.9287 - val_y1_output_loss: 0.1973 - val_y2_output_loss: 0.7344 - val_y1_output_root_mean_squared_error: 0.4517 - val_y2_output_root_mean_squared_error: 0.8512
# Epoch 478/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3909 - y1_output_loss: 0.1234 - y2_output_loss: 0.2709 - y1_output_root_mean_squared_error: 0.3521 - y2_output_root_mean_squared_error: 0.5167 - val_loss: 0.7914 - val_y1_output_loss: 0.1737 - val_y2_output_loss: 0.6461 - val_y1_output_root_mean_squared_error: 0.4206 - val_y2_output_root_mean_squared_error: 0.7839
# Epoch 479/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4873 - y1_output_loss: 0.1453 - y2_output_loss: 0.3381 - y1_output_root_mean_squared_error: 0.3826 - y2_output_root_mean_squared_error: 0.5838 - val_loss: 0.6870 - val_y1_output_loss: 0.1730 - val_y2_output_loss: 0.5011 - val_y1_output_root_mean_squared_error: 0.4209 - val_y2_output_root_mean_squared_error: 0.7141
# Epoch 480/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3662 - y1_output_loss: 0.1144 - y2_output_loss: 0.2518 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.5028 - val_loss: 0.6967 - val_y1_output_loss: 0.2096 - val_y2_output_loss: 0.4783 - val_y1_output_root_mean_squared_error: 0.4606 - val_y2_output_root_mean_squared_error: 0.6961
# Epoch 481/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4740 - y1_output_loss: 0.1364 - y2_output_loss: 0.3406 - y1_output_root_mean_squared_error: 0.3662 - y2_output_root_mean_squared_error: 0.5830 - val_loss: 1.0553 - val_y1_output_loss: 0.3380 - val_y2_output_loss: 0.6855 - val_y1_output_root_mean_squared_error: 0.5913 - val_y2_output_root_mean_squared_error: 0.8400
# Epoch 482/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3839 - y1_output_loss: 0.1251 - y2_output_loss: 0.2746 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.5110 - val_loss: 4.7334 - val_y1_output_loss: 0.4969 - val_y2_output_loss: 4.2569 - val_y1_output_root_mean_squared_error: 0.7121 - val_y2_output_root_mean_squared_error: 2.0558
# Epoch 483/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.7219 - y1_output_loss: 0.1747 - y2_output_loss: 0.5492 - y1_output_root_mean_squared_error: 0.4147 - y2_output_root_mean_squared_error: 0.7416 - val_loss: 0.7219 - val_y1_output_loss: 0.1909 - val_y2_output_loss: 0.5204 - val_y1_output_root_mean_squared_error: 0.4414 - val_y2_output_root_mean_squared_error: 0.7260
# Epoch 484/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3559 - y1_output_loss: 0.1152 - y2_output_loss: 0.2378 - y1_output_root_mean_squared_error: 0.3410 - y2_output_root_mean_squared_error: 0.4895 - val_loss: 0.7152 - val_y1_output_loss: 0.1927 - val_y2_output_loss: 0.5082 - val_y1_output_root_mean_squared_error: 0.4407 - val_y2_output_root_mean_squared_error: 0.7217
# Epoch 485/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3810 - y1_output_loss: 0.1382 - y2_output_loss: 0.2463 - y1_output_root_mean_squared_error: 0.3733 - y2_output_root_mean_squared_error: 0.4916 - val_loss: 1.7009 - val_y1_output_loss: 0.2248 - val_y2_output_loss: 1.4492 - val_y1_output_root_mean_squared_error: 0.4730 - val_y2_output_root_mean_squared_error: 1.2154
# Epoch 486/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.6055 - y1_output_loss: 0.1730 - y2_output_loss: 0.4277 - y1_output_root_mean_squared_error: 0.4171 - y2_output_root_mean_squared_error: 0.6569 - val_loss: 0.6781 - val_y1_output_loss: 0.1868 - val_y2_output_loss: 0.4868 - val_y1_output_root_mean_squared_error: 0.4357 - val_y2_output_root_mean_squared_error: 0.6988
# Epoch 487/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2846 - y1_output_loss: 0.1094 - y2_output_loss: 0.1888 - y1_output_root_mean_squared_error: 0.3273 - y2_output_root_mean_squared_error: 0.4213 - val_loss: 2.2118 - val_y1_output_loss: 0.4049 - val_y2_output_loss: 1.8469 - val_y1_output_root_mean_squared_error: 0.6402 - val_y2_output_root_mean_squared_error: 1.3424
# Epoch 488/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4425 - y1_output_loss: 0.1316 - y2_output_loss: 0.3094 - y1_output_root_mean_squared_error: 0.3643 - y2_output_root_mean_squared_error: 0.5566 - val_loss: 0.7023 - val_y1_output_loss: 0.1878 - val_y2_output_loss: 0.4943 - val_y1_output_root_mean_squared_error: 0.4410 - val_y2_output_root_mean_squared_error: 0.7127
# Epoch 489/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3172 - y1_output_loss: 0.1101 - y2_output_loss: 0.2058 - y1_output_root_mean_squared_error: 0.3314 - y2_output_root_mean_squared_error: 0.4554 - val_loss: 0.6509 - val_y1_output_loss: 0.1982 - val_y2_output_loss: 0.4480 - val_y1_output_root_mean_squared_error: 0.4433 - val_y2_output_root_mean_squared_error: 0.6741
# Epoch 490/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3959 - y1_output_loss: 0.1202 - y2_output_loss: 0.2779 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.5249 - val_loss: 0.9323 - val_y1_output_loss: 0.2342 - val_y2_output_loss: 0.7187 - val_y1_output_root_mean_squared_error: 0.4883 - val_y2_output_root_mean_squared_error: 0.8330
# Epoch 491/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4171 - y1_output_loss: 0.1205 - y2_output_loss: 0.2933 - y1_output_root_mean_squared_error: 0.3481 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 0.6933 - val_y1_output_loss: 0.1819 - val_y2_output_loss: 0.4965 - val_y1_output_root_mean_squared_error: 0.4318 - val_y2_output_root_mean_squared_error: 0.7119
# Epoch 492/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3136 - y1_output_loss: 0.1011 - y2_output_loss: 0.2150 - y1_output_root_mean_squared_error: 0.3180 - y2_output_root_mean_squared_error: 0.4610 - val_loss: 1.4020 - val_y1_output_loss: 0.2019 - val_y2_output_loss: 1.1593 - val_y1_output_root_mean_squared_error: 0.4545 - val_y2_output_root_mean_squared_error: 1.0934
# Epoch 493/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4552 - y1_output_loss: 0.1350 - y2_output_loss: 0.3166 - y1_output_root_mean_squared_error: 0.3691 - y2_output_root_mean_squared_error: 0.5647 - val_loss: 0.8885 - val_y1_output_loss: 0.1982 - val_y2_output_loss: 0.6699 - val_y1_output_root_mean_squared_error: 0.4498 - val_y2_output_root_mean_squared_error: 0.8283
# Epoch 494/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4298 - y1_output_loss: 0.1226 - y2_output_loss: 0.3093 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5547 - val_loss: 1.5415 - val_y1_output_loss: 0.2451 - val_y2_output_loss: 1.3055 - val_y1_output_root_mean_squared_error: 0.4972 - val_y2_output_root_mean_squared_error: 1.1377
# Epoch 495/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3745 - y1_output_loss: 0.1226 - y2_output_loss: 0.2503 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5012 - val_loss: 0.7710 - val_y1_output_loss: 0.2199 - val_y2_output_loss: 0.5387 - val_y1_output_root_mean_squared_error: 0.4700 - val_y2_output_root_mean_squared_error: 0.7417
# Epoch 496/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3694 - y1_output_loss: 0.1060 - y2_output_loss: 0.2624 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.5130 - val_loss: 1.0125 - val_y1_output_loss: 0.2523 - val_y2_output_loss: 0.7468 - val_y1_output_root_mean_squared_error: 0.5029 - val_y2_output_root_mean_squared_error: 0.8715
# Epoch 497/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4229 - y1_output_loss: 0.1369 - y2_output_loss: 0.2847 - y1_output_root_mean_squared_error: 0.3718 - y2_output_root_mean_squared_error: 0.5335 - val_loss: 0.7549 - val_y1_output_loss: 0.1736 - val_y2_output_loss: 0.5763 - val_y1_output_root_mean_squared_error: 0.4219 - val_y2_output_root_mean_squared_error: 0.7595
# Epoch 498/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3362 - y1_output_loss: 0.1139 - y2_output_loss: 0.2194 - y1_output_root_mean_squared_error: 0.3388 - y2_output_root_mean_squared_error: 0.4706 - val_loss: 0.6957 - val_y1_output_loss: 0.1906 - val_y2_output_loss: 0.4933 - val_y1_output_root_mean_squared_error: 0.4406 - val_y2_output_root_mean_squared_error: 0.7082
# Epoch 499/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3115 - y1_output_loss: 0.1078 - y2_output_loss: 0.2025 - y1_output_root_mean_squared_error: 0.3291 - y2_output_root_mean_squared_error: 0.4508 - val_loss: 0.7245 - val_y1_output_loss: 0.1949 - val_y2_output_loss: 0.5166 - val_y1_output_root_mean_squared_error: 0.4476 - val_y2_output_root_mean_squared_error: 0.7240
# Epoch 500/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3749 - y1_output_loss: 0.1209 - y2_output_loss: 0.2576 - y1_output_root_mean_squared_error: 0.3486 - y2_output_root_mean_squared_error: 0.5033 - val_loss: 1.0693 - val_y1_output_loss: 0.2253 - val_y2_output_loss: 0.8154 - val_y1_output_root_mean_squared_error: 0.4835 - val_y2_output_root_mean_squared_error: 0.9141

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 705us/sample - loss: 1.0693 - y1_output_loss: 0.2287 - y2_output_loss: 0.8377 - y1_output_root_mean_squared_error: 0.4835 - y2_output_root_mean_squared_error: 0.9141
# Loss = 1.069306081765658, Y1_loss = 0.2286645621061325, Y1_mse = 0.4835353195667267, Y2_loss = 0.8376714587211609, Y2_mse = 0.9140567183494568

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
